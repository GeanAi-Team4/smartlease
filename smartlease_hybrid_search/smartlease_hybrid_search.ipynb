# %% [markdown]
# # Smartlease Hybrid Search System

# %% [markdown]
# # Take User Input:
#
# * Prompts the user to enter a property search query (example: "Looking for a 2BHK in Boston under $3000").
#
# # Refine Query (OpenAI GPT-4):
#
# * Uses GPT-4 to rephrase the query into a cleaner, semantically rich version for better embedding.
#
# # Extract Address (Regex):
#
# * Optionally pulls out the address part from the query (if available), used later for result context.
#
# # Generate Embedding:
#
# * Sends the refined query to OpenAI's text-embedding-ada-002 model to get a vector representation.
#
# # Semantic Search (Pinecone):
#
# * Uses the embedding to search the Pinecone vector DB for top-matching property embeddings.
#
# * Returns metadata of top matches.
#
# # Post-Filter & Format (OpenAI GPT-4):
#
# * Sends search results and query context to GPT-4.
#
# * GPT-4 filters and formats the matches into structured JSON.
#
# # Store Output in JSON:
#
# * Saves the final results (with original query + metadata) to a file query_metadata_log.json.

# %%
import openai
import json
import os

# Set your OpenAI API key
openai.api_key = "" 

def extract_metadata_from_query(user_query: str) -> dict:
    system_prompt = """
You are an intelligent assistant that extracts structured metadata from real estate search queries.

Extract only the fields that are mentioned in the user query. Return the output in JSON format.

Valid metadata fields:
- PROPERTY_ID
- PROPERTY_TITLE
- PROPERTY_ADDRESS
- MONTHLY_RENT
- BEDROOMS
- BATHROOMS
- SQUARE_FEET
- AVAILABILITY
- DEPOSIT
- LEASE_DURATION
- HOUSE_FEATURES
- UTILITIES_INCLUDED
- ABOUT_PROPERTY_DETAILS
- NEIGHBORHOOD_DETAILS
- ADDITIONAL_PROPERTY_DETAILS
- PROPERTY_IMAGE_FOLDER_S3_PATH
"""

    user_prompt = f"User Query: {user_query}\n\nReturn metadata in JSON format."

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",  # or gpt-3.5-turbo
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            temperature=0.2
        )

        raw_content = response["choices"][0]["message"]["content"]
        metadata_json = json.loads(raw_content)

        return {
            "user_query": user_query,
            "metadata_extracted": metadata_json
        }

    except json.JSONDecodeError:
        return {
            "error": "Could not parse response as JSON",
            "raw_response": raw_content
        }
    except Exception as e:
        return {
            "error": str(e)
        }


def save_metadata_to_json(output: dict, filepath: str = "query_metadata_log.json"):
    # Check if file exists; if not, create a new list
    if os.path.exists(filepath):
        with open(filepath, "r") as f:
            try:
                existing_data = json.load(f)
            except json.JSONDecodeError:
                existing_data = []
    else:
        existing_data = []

    # Append new output
    existing_data.append(output)

    # Write back to file
    with open(filepath, "w") as f:
        json.dump(existing_data, f, indent=2)

    print(f"Metadata saved to {filepath}")



# Prompt user input
if __name__ == "__main__":
    # print("Welcome to SmartLease Property Finder!")
    query = input("Please enter your property requirement, like: 2-bedroom apartment in Boston under $3000 with parking'):\n> ")
    result = extract_metadata_from_query(query)
    print("Extracted Metadata:")
    print(json.dumps(result, indent=2))

    #Save metadata to query_metadata_log.json
    save_metadata_to_json(result)
    # print("Metadata saved to query_metadata_log.json")
# Out:
# Please enter your property requirement, like: 2-bedroom apartment in Boston under $3000 with parking'):
# >  Give me properties with 5 bedrooms and rent can be 5200  and is closest to Wentworth Institute of Technology based on drive distance in miles
# Extracted Metadata:
# {
#   "user_query": "Give me properties with 5 bedrooms and rent can be 5200  and is closest to Wentworth Institute of Technology based on drive distance in miles",
#   "metadata_extracted": {
#     "BEDROOMS": 5,
#     "MONTHLY_RENT": 5200,
#     "PROPERTY_ADDRESS": "Wentworth Institute of Technology"
#   }
# }
# Metadata saved to query_metadata_log.json

# %% [markdown]
# # Connect to Snowflake DB and test connection

# %%
# ! pip install snowflake-connector-python

# %%
import snowflake.connector

# Snowflake credentials
SNOWFLAKE_ACCOUNT = "SFEDU02-PDB57018"
SNOWFLAKE_USER = "BADGER"
# Not needed with externalbrowser authentication
SNOWFLAKE_PASSWORD = ""  
SNOWFLAKE_AUTHENTICATOR = "externalbrowser"
SNOWFLAKE_ROLE = "TRAINING_ROLE"
SNOWFLAKE_DATABASE = "LISTINGS" 
SNOWFLAKE_SCHEMA = "PUBLIC"    
SNOWFLAKE_WAREHOUSE = "LISTINGS_WH" 

# Connect to Snowflake
conn = snowflake.connector.connect(
    user=SNOWFLAKE_USER,
    password=SNOWFLAKE_PASSWORD,
    account=SNOWFLAKE_ACCOUNT,
    warehouse=SNOWFLAKE_WAREHOUSE,
    database=SNOWFLAKE_DATABASE,
    schema=SNOWFLAKE_SCHEMA
)

# Create a cursor to run queries
cursor = conn.cursor()

# Test query
try:
    cursor.execute("SELECT * FROM PROPERTIES_WITH_EMBEDDINGS LIMIT 1;")

    result = cursor.fetchall()
    print("Connection successful! Sample row:\n")

    print(result)

except Exception as e:
    print("Connection failed:", str(e))
finally:
    cursor.close()
    conn.close()
# Out:
# Connection successful! Sample row:
#
# [('property_1', '29 woodford st', '29 woodford st, boston, ma 02125', 'rent: $5,000', '4 bedrooms', '3 bathrooms', '2,000 square feet', 'available now', None, None, 'amenities: kitchen, refrigerator', None, "this spacious townhouse offers 3 bedrooms, 2.5 bathrooms, and 2 garage spaces. the home features a private deck and a separate balcony for outdoor enjoyment. the master suite, located on the top floor, includes a walk-in closet, double vanity, standing glass shower, and a ceramic tub. built-in furniture designs throughout provide ready spaces for electronics, with a built-in desk area along the walkway. located in a prime boston area, just steps from upham's corner station, this home offers easy access to downtown boston, northeastern university, and massart at ruggles station.in addition to public schools, nearby private school options include the epiphany school and boston college high school. you ll also enjoy proximity to shopping centers, including south bay center and boston public market, making errands and entertainment convenient. 29 woodford st is a house located in suffolk county and the 02125 zip code. this area is served by the boston public schools attendance zone.", 'less than four miles outside of downtown boston sits dudley-brunswick king. full of non-profit organizations committed to advancing the community, dudley-brunswick king is home to the food project, commonwealth kitchen, project hope, and the dudley street neighborhood initiative. dudley-brunswick king residents enjoy access to cultural and educational venues such as the boston public library and oodua african movie center. there are a number of parks and green spaces in dudley-brunswick king including clifford playground, mary hannon park, ceylon park, brunswick-king play area, dacia/woodcliff streets garden, and multiple community gardens sponsored by the food project. boston’s biggest park, franklin park, is also nearby and contains numerous amenities. convenient to the mbta commuter rail, bus routes, and major highways as well as boston logan international airport, dudley-brunswick king allows for easy commutes and travels.', "education\ncolleges & universities distance\numass boston\ndrive: 6 min 2.2 mi\nwentworth inst. of technology\ndrive: 5 min 2.4 mi\nnortheastern university\ndrive: 6 min 2.5 mi\nmassart\ndrive: 5 min 2.7 mi\n29 woodford st is within 6 minutes or 2.5 miles from northeastern university. it is also near wentworth inst. of technology and umass boston.\nschools\npublic schools private schools\ndudley street neighborhood charter school\ncharter elementary school\ngrades pk-5\n278 students\nattendance zone\n3\nout of 10\nhaynes early education center\npublic elementary school\ngrades pk-1\n203 students\nattendance zone\nlilla g. frederick middle school\npublic middle school\ngrades 6-8\n323 students\nattendance zone\n3\nout of 10\nboston latin academy\npublic middle & high school\ngrades 7-12\n1,723 students\nattendance zone\n7\nout of 10\njeremiah e burke high\npublic middle & high school\ngrades 7-12\n420 students\nattendance zone\n2\nout of 10\nboston day and evening academy charter school\ncharter high school\ngrades 9-10 & 12\n321 students\nattendance zone\n1\nout of 10\nschool data provided by greatschools\n\ntransportation\ntransportation options available in boston include andrew station, located 1.5 miles from 29 woodford st. 29 woodford st is near general edward lawrence logan international, located 6.3 miles or 12 minutes away.\ntransit / subway distance\nandrew station\ndrive: 3 min 1.5 mi\nfields corner station\ndrive: 5 min 1.9 mi\nsavin hill station\ndrive: 4 min 1.9 mi\nroxbury crossing station\ndrive: 4 min 2.0 mi\njackson square station\ndrive: 5 min 2.5 mi\ncommuter rail distance\nuphams corner\nwalk: 6 min 0.3 mi\nfour corners/geneva\ndrive: 3 min 1.3 mi\nnewmarket\ndrive: 2 min 1.3 mi\njfk/umass\ndrive: 4 min 1.6 mi\nruggles station\ndrive: 6 min 2.9 mi\nairports distance\ngeneral edward lawrence logan int ...

# %% [markdown]
# # Hybrid Snowflake Search

# %%
import snowflake.connector
import json

# Load latest metadata entry from local JSON
with open("query_metadata_log.json", "r") as f:
    data = json.load(f)

latest = data[-1]
user_query = latest["user_query"]
metadata_filters = latest["metadata_extracted"]

# Sanitize user query for embedding call inside SQL
user_query_safe = user_query.replace("'", "''")

# Connect to Snowflake
conn = snowflake.connector.connect(
    account="SFEDU02-PDB57018",
    user="BADGER",
    password="",
    role="TRAINING_ROLE",
    warehouse="LISTINGS_WH",
    database="LISTINGS",
    schema="PUBLIC"
)
cur = conn.cursor()

# Build metadata filter WHERE clause
filter_clauses = []
for key, value in metadata_filters.items():
    if value:
        if isinstance(value, (int, float)):
            filter_clauses.append(f"{key} = {value}")
        elif isinstance(value, str) and value.strip().startswith("<"):
            num = value.strip("<$ ")
            filter_clauses.append(f"TRY_TO_NUMBER(REGEXP_REPLACE({key}, '[^0-9.]', '')) < {num}")
        elif isinstance(value, str) and value.strip().startswith(">"):
            num = value.strip(">$ ")
            filter_clauses.append(f"TRY_TO_NUMBER(REGEXP_REPLACE({key}, '[^0-9.]', '')) > {num}")
        elif isinstance(value, bool):
            filter_clauses.append(f"{key} = {str(value).upper()}")
        else:
            filter_clauses.append(f"{key} ILIKE '%{value}%'")

where_clause = " AND ".join(filter_clauses)
if where_clause:
    where_clause = f"WHERE {where_clause}"

# SQL with filters (hybrid search)
sql_with_filters = f"""
SELECT *,
  VECTOR_COSINE_SIMILARITY(
    PROPERTIES_EMBEDDING,
    SNOWFLAKE.CORTEX.EMBED_TEXT_1024('snowflake-arctic-embed-l-v2.0', '{user_query_safe}')
  ) AS similarity
FROM PROPERTIES_WITH_EMBEDDINGS
{where_clause}
ORDER BY similarity DESC
LIMIT 10;
"""

print("Executing hybrid query with filters...\n")
print(sql_with_filters)

# Run hybrid query
cur.execute(sql_with_filters)
results = cur.fetchall()

# If no results, fallback to semantic-only
if not results:
    print("\nNo results found with metadata filters. Trying semantic-only fallback...\n")

    sql_no_filters = f"""
    SELECT *,
      VECTOR_COSINE_SIMILARITY(
        PROPERTIES_EMBEDDING,
        SNOWFLAKE.CORTEX.EMBED_TEXT_1024('snowflake-arctic-embed-l-v2.0', '{user_query_safe}')
      ) AS similarity
    FROM PROPERTIES_WITH_EMBEDDINGS
    ORDER BY similarity DESC
    LIMIT 10;
    """

    print("Fallback Query:\n", sql_no_filters)
    cur.execute(sql_no_filters)
    results = cur.fetchall()

# Safely fetch columns after query execution
columns = [col[0] for col in cur.description]

# Show results
if not results:
    print("\nNo matching properties found even after fallback.\n")
else:
    print("\nTop matching properties:\n")
    for row in results:
        print(dict(zip(columns, row)))

cur.close()
conn.close()
# Out:
# 🔍 Executing hybrid query with filters...
#
#
# SELECT *,
#   VECTOR_COSINE_SIMILARITY(
#     PROPERTIES_EMBEDDING,
#     SNOWFLAKE.CORTEX.EMBED_TEXT_1024('snowflake-arctic-embed-l-v2.0', 'Give me properties with 5 bedrooms and rent can be 5200  and is closest to Wentworth Institute of Technology based on drive distance in miles')
#   ) AS similarity
# FROM PROPERTIES_WITH_EMBEDDINGS
# WHERE BEDROOMS ILIKE '%5 BEDROOMS%' AND MONTHLY_RENT ILIKE '%Rent: $5,200%' AND PROPERTY_ADDRESS ILIKE '%Wentworth Institute of Technology%'
# ORDER BY similarity DESC
# LIMIT 10;
#
#
# ⚠️ No results found with metadata filters. Trying semantic-only fallback...
#
# 🔁 Fallback Query:
#
#     SELECT *,
#       VECTOR_COSINE_SIMILARITY(
#         PROPERTIES_EMBEDDING,
#         SNOWFLAKE.CORTEX.EMBED_TEXT_1024('snowflake-arctic-embed-l-v2.0', 'Give me properties with 5 bedrooms and rent can be 5200  and is closest to Wentworth Institute of Technology based on drive distance in miles')
#       ) AS similarity
#     FROM PROPERTIES_WITH_EMBEDDINGS
#     ORDER BY similarity DESC
#     LIMIT 10;
#
#
# ✅ Top matching properties:
#
# {'PROPERTY_ID': 'property_181', 'PROPERTY_TITLE': '13 gordon st', 'PROPERTY_ADDRESS': '13 gordon st, boston, ma 02130', 'MONTHLY_RENT': 'rent: $5,200', 'BEDROOMS': '5 bedrooms', 'BATHROOMS': '2.5 bathrooms', 'SQUARE_FEET': '9,999 square feet', 'AVAILABILITY': 'available sep 1, 2025', 'DEPOSIT': '$5,200 deposit', 'LEASE_DURATION': '12 month lease', 'HOUSE_FEATURES': 'amenities: washer/dryer', 'UTILITIES_INCLUDED': None, 'ABOUT_PROPERTY_DETAILS': 'come home to this great property in boston, ma. this property is located at 13 gordon st in the 2130 area of boston. stop looking and find your new home. to learn more about this property, contact us to schedule a tour. 13 gordon st is a house located in suffolk county and the 02130 zip code.', 'NEIGHBORHOOD_DETAILS': "jamaica central-south sumner is a section of jamaica plain spanning north of arborway road. the verdant area is made up of good schools, peaceful communities, scenic views, and easy access to surrounding cities, including boston. boston's excellent mass transit system, which includes buses, subways, and light rail, serves this neighborhood. the southern portion of the neighborhood partially encompasses arnold arboretum of harvard university while the western side features willow pond meadow as well as the hellenic college and holy cross greek orthodox school of theology. a variety of shopping and dining choices are located along centre street. the rest of the neighborhood is filled with residential homes complemented by lush greenery.", 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\nwentworth inst. of technology\ndrive: 5 min 2.4 mi\nmassart\ndrive: 5 min 2.9 mi\nmcphs university, boston\ndrive: 6 min 3.0 mi\nsimmons college\ndrive: 8 min 3.7 mi\n13 gordon st is within 5 minutes or 2.4 miles from wentworth inst. of technology. it is also near mcphs university, boston and massart.\n\ntransportation\ntransportation options available in boston include green street station, located 0.1 miles from 13 gordon st. 13 gordon st is near general edward lawrence logan international, located 7.7 miles or 16 minutes away.\ntransit / subway distance\ngreen street station\nwalk: 1 min 0.1 mi\nstony brook station\nwalk: 10 min 0.5 mi\nforest hills station\nwalk: 16 min 0.8 mi\njackson square station\ndrive: 3 min 1.3 mi\nheath street station\ndrive: 4 min 1.5 mi\ncommuter rail distance\nforest hills\nwalk: 16 min 0.8 mi\nroslindale village\ndrive: 7 min 2.5 mi\nfour corners/geneva\ndrive: 6 min 2.5 mi\nruggles station\ndrive: 6 min 3.0 mi\ntalbot avenue\ndrive: 7 min 3.1 mi\nairports distance\ngeneral edward lawrence logan international\ndrive: 16 min 7.7 mi\n\nwalker's paradise\n90\nwalk score®\nout of 100\nlace up your walking shoes because this area is considered a walker’s paradise.\nexcellent transit\n74\ntransit score®\nout of 100\nyou’ll have excellent transit living in this area, with several nearby transit stops.\nbiker's paradise\n96\nbike score®\nout of 100\ndo you prefer to get around on two wheels? you’ll love living in this neighborhood, which is considered a biker’s paradise.\n-\n-\nsoundscore™\nout of 100\ntraffic:\n-\nairport:\n-\nbusinesses:\n-\nscore provided by walk score\n\npoints of interest\ntime and distance from 13 gordon st.\nshopping centers distance\nthe mecca at grove hall\ndrive: 5 min 1.9 mi\nwashington park shopping mall\ndrive: 4 min 2.1 mi\nlegion shopping center\ndrive: 6 min 2.2 mi\n13 gordon st has 3 shopping centers within 2.2 miles, which is about a 6-minute drive. the miles and minutes will be for the farthest away property.\nparks and recreation distance\nlower neponset river trail\ndrive: 5 min 1.8 mi\nfranklin park zoo\ndrive: 5 min 2.0 mi\narnold arboretum of harvard university\ndrive: 5 min 2.1 mi\nroxbury heritage state park\ndrive: 4 min 2.3 mi\nfrederick law olmsted national historic site\ndrive: 7 min 2.4 mi\n13 gordon st has 5 parks within 2.4 miles, including lower neponset river trail, franklin park zoo, an ...
# {'PROPERTY_ID': 'property_208', 'PROPERTY_TITLE': '1 cedar st', 'PROPERTY_ADDRESS': '1 cedar st, boston, ma 02119', 'MONTHLY_RENT': 'rent: $8,750', 'BEDROOMS': '7 bedrooms', 'BATHROOMS': '4.5 bathrooms', 'SQUARE_FEET': '3,000 square feet', 'AVAILABILITY': 'available now', 'DEPOSIT': '$9,150 deposit', 'LEASE_DURATION': None, 'HOUSE_FEATURES': None, 'UTILITIES_INCLUDED': None, 'ABOUT_PROPERTY_DETAILS': "you'll adore your new rental in boston, ma. rent at this 1 cedar st location in boston and enjoy a great neighborhood and a variety of destinations. with this great space, you're right at home. reach out to learn more about this great rental. 1 cedar st is a house located in suffolk county and the 02119 zip code. this area is served by the boston public schools attendance zone.", 'NEIGHBORHOOD_DETAILS': 'twenty minutes southwest of downtown boston sits highland park, a primarily- residential neighborhood full of beautiful historic homes and apartments along tree-lined streets. the community features over a dozen parks and public green spaces, giving all residents easy access to trails, playgrounds, and historic sites wherever they may live. the local dining scene is quite unique, with several african and middle eastern restaurants and cafes around the neighborhood. mbta rail service on the west side of the neighborhood makes it easy for folks to get around the city for or leisure.', 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\nwentworth inst. of technology\ndrive: 3 min 1.3 mi\nmassart\ndrive: 3 min 1.8 mi\nmcphs university, boston\ndrive: 4 min 1.9 mi\nnortheastern university\ndrive: 5 min 2.0 mi\n1 cedar st is within 3 minutes or 1.3 miles from wentworth inst. of technology. it is also near northeastern university and mcphs university, boston.\nschools\npublic schools private schools\nhigginson/lewis k-8\npublic elementary & middle school\ngrades 3-8\n177 students\nattendance zone\n2\nout of 10\nhale elementary school\npublic elementary school\ngrades pk-6\n169 students\nattendance zone\n6\nout of 10\no'bryant school math/science\npublic middle & high school\ngrades 7-12\n1,567 students\nattendance zone\n8\nout of 10\njames p timilty middle\npublic middle school\ngrades 6-8\n205 students\nattendance zone\nmadison park high\npublic high school\ngrades 9-12\n1,087 students\nattendance zone\n1\nout of 10\nboston day and evening academy charter school\ncharter high school\ngrades 9-10 & 12\n321 students\nattendance zone\n1\nout of 10\nschool data provided by greatschools\n\ntransportation\ntransportation options available in boston include roxbury crossing station, located 0.7 miles from 1 cedar st. 1 cedar st is near general edward lawrence logan international, located 6.2 miles or 12 minutes away.\ntransit / subway distance\nroxbury crossing station\nwalk: 14 min 0.7 mi\njackson square station\nwalk: 15 min 0.8 mi\nstony brook station\ndrive: 3 min 1.3 mi\nmuseum of fine arts station\ndrive: 3 min 1.6 mi\nlongwood medical area station\ndrive: 4 min 1.6 mi\ncommuter rail distance\nnewmarket\ndrive: 3 min 1.6 mi\nuphams corner\ndrive: 3 min 1.6 mi\nruggles station\ndrive: 4 min 1.9 mi\nfour corners/geneva\ndrive: 5 min 2.1 mi\nyawkey\ndrive: 10 min 5.3 mi\nairports distance\ngeneral edward lawrence logan international\ndrive: 12 min 6.2 mi\n\nvery walkable\n79\nwalk score®\nout of 100\nif you enjoy walking, you’ll enjoy renting in this area! it’s a very walkable neighborhood.\nexcellent transit\n81\ntransit score®\nout of 100\nyou’ll have excellent transit living in this area, with several nearby transit stops.\nbikeable\n65\nbike score®\nout of 100\nwhile there’s some bike infrastructure in this area, you’ll still need a car for many errands.\n-\n-\nsoundscore™\nout of 100\ntraffic:\n-\nairport:\n-\nbusinesses:\n-\nscore provided by walk score\n\npoints of interest\ntime and distance from 1 cedar st.\nshopping centers distance\nwashington park shopping mall\nwalk: 13 min 0.7 mi\nthe mecca at grove h ...
# {'PROPERTY_ID': 'property_169', 'PROPERTY_TITLE': '1110 washington st', 'PROPERTY_ADDRESS': '1110 washington st, boston, ma 02124', 'MONTHLY_RENT': 'rent: $3,600', 'BEDROOMS': '2 bedrooms', 'BATHROOMS': '1.5 bathrooms', 'SQUARE_FEET': '1,932 square feet', 'AVAILABILITY': 'available now', 'DEPOSIT': '$4,400 deposit', 'LEASE_DURATION': None, 'HOUSE_FEATURES': None, 'UTILITIES_INCLUDED': None, 'ABOUT_PROPERTY_DETAILS': "a beautiful victorian brick & masonry structure located at the corner of richmond st in dorchester's trending lower mills. the main entrance leads to the great room which still retains its tin ceilings,plaster detail,marble fireplace & original pine floors. this leads to a meeting room with oversized windows. off the great room is a large office which includes the original walk in vault. an oversized living/conference room includes plenty of double height storage closets,the generous commercial grade kitchen,full bath with steam shower & welcoming rear foyer complete the main floor. downstairs there is a partially finished basement which features a half bath & office. 3 reserved parking spots and only 10 minutes from the red line. 1110 washington st is a house located in suffolk county and the 02124 zip code. this area is served by the boston public schools attendance zone.", 'NEIGHBORHOOD_DETAILS': 'west codman hill-west lower mills is located 10 miles outside of boston. the lower mills district was added to the national register of historic places and is home to a large industrial factory complex— once associated with the oldest producer of chocolate in the united states. for outdoor recreation, visit roberts playground, offering soccer fields, a basketball court, and a field hockey area. along the southern border of town lies the neponset river, where residents have access to trails for biking and running. contemporary and colonial-style houses are popular in the area.', 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\numass boston\ndrive: 9 min 4.5 mi\ncurry college\ndrive: 11 min 4.6 mi\nwentworth inst. of technology\ndrive: 10 min 5.5 mi\nmassart\ndrive: 10 min 6.0 mi\n1110 washington st is within 11 minutes or 4.6 miles from curry college. it is also near umass boston and wentworth inst. of technology.\nschools\npublic schools private schools\nhenderson k-12 inclusion school upper\npublic elementary, middle & high school\ngrades 2-12\n666 students\nattendance zone\n2\nout of 10\ntaylor elementary school\npublic elementary school\ngrades pk-6\n358 students\nattendance zone\n2\nout of 10\ndearborn middle school\npublic middle & high school\ngrades 6-12\n541 students\nattendance zone\n3\nout of 10\ntechboston academy\npublic middle & high school\ngrades 6-12\n871 students\nattendance zone\n2\nout of 10\ndorchester academy\npublic high school\ngrades 9-12\n42 students\nattendance zone\nboston international high school\npublic high school\ngrades 9-12\n472 students\nattendance zone\n3\nout of 10\nschool data provided by greatschools\n\ntransportation\ntransportation options available in boston include milton station, located 0.4 miles from 1110 washington st. 1110 washington st is near general edward lawrence logan international, located 9.9 miles or 17 minutes away.\ntransit / subway distance\nmilton station\nwalk: 7 min 0.4 mi\ncentral avenue station\nwalk: 8 min 0.5 mi\nbutler station\nwalk: 9 min 0.5 mi\ncedar grove station\nwalk: 14 min 0.8 mi\nvalley road station\nwalk: 18 min 0.9 mi\ncommuter rail distance\nmorton street\nwalk: 18 min 1.0 mi\ntalbot avenue\ndrive: 4 min 1.5 mi\nblue hill avenue\ndrive: 4 min 2.0 mi\nfour corners/geneva\ndrive: 6 min 3.3 mi\nfairmount\ndrive: 8 min 3.4 mi\nairports distance\ngeneral edward lawrence logan international\ndrive: 17 min 9.9 mi\n\nvery walkable\n85\nwalk score®\nout of 100\nif you enjoy walking, you’ll enjoy renting in this area! it’s a very walkable neighborhood.\ngood transit\n67\ntransit score®\nout of 100\nthe area around this pr ...
# {'PROPERTY_ID': 'property_168', 'PROPERTY_TITLE': '1 cedar sq', 'PROPERTY_ADDRESS': '1 cedar sq, boston, ma 02119', 'MONTHLY_RENT': 'rent: $9,500', 'BEDROOMS': '6 bedrooms', 'BATHROOMS': '4.5 bathrooms', 'SQUARE_FEET': '3,000 square feet', 'AVAILABILITY': 'available sep 1, 2025', 'DEPOSIT': None, 'LEASE_DURATION': '12 month lease', 'HOUSE_FEATURES': 'amenities: washer/dryer, air conditioning, heating, cable ready, storage space', 'UTILITIES_INCLUDED': 'water, trash removal, sewer', 'ABOUT_PROPERTY_DETAILS': "available september 1, 2025\nnew single-family house in mission hill\nrecently renovated\nin-unit washer and dryer\ncentral heat/ac\npets friendly\n3000s.f of the living space\nlarge bedrooms\neat-in kitchen\nstainless steel kitchen appliances\nit's a must-see house\nproperty info\n\nrent: $9,500 / month\nbeds: 7\nbath: 4.5\navailable date: 09/01/2025\npet: pet friendly\nparking:: no parking\n\nfeatures\ncentral air 1 cedar sq is a house located in suffolk county and the 02119 zip code. this area is served by the boston public schools attendance zone.", 'NEIGHBORHOOD_DETAILS': 'twenty minutes southwest of downtown boston sits highland park, a primarily- residential neighborhood full of beautiful historic homes and apartments along tree-lined streets. the community features over a dozen parks and public green spaces, giving all residents easy access to trails, playgrounds, and historic sites wherever they may live. the local dining scene is quite unique, with several african and middle eastern restaurants and cafes around the neighborhood. mbta rail service on the west side of the neighborhood makes it easy for folks to get around the city for or leisure.', 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\nwentworth inst. of technology\ndrive: 3 min 1.3 mi\nmassart\ndrive: 3 min 1.7 mi\nmcphs university, boston\ndrive: 3 min 1.8 mi\nnortheastern university\ndrive: 5 min 2.1 mi\n1 cedar sq is within 3 minutes or 1.3 miles from wentworth inst. of technology. it is also near mcphs university, boston and massart.\nschools\npublic schools private schools\nhale elementary school\npublic elementary school\ngrades pk-6\n169 students\nattendance zone\n6\nout of 10\nhigginson/lewis k-8\npublic elementary & middle school\ngrades 3-8\n177 students\nattendance zone\n2\nout of 10\njames p timilty middle\npublic middle school\ngrades 6-8\n205 students\nattendance zone\no'bryant school math/science\npublic middle & high school\ngrades 7-12\n1,567 students\nattendance zone\n8\nout of 10\nboston day and evening academy charter school\ncharter high school\ngrades 9-10 & 12\n321 students\nattendance zone\n1\nout of 10\nmadison park high\npublic high school\ngrades 9-12\n1,087 students\nattendance zone\n1\nout of 10\nschool data provided by greatschools\n\ntransportation\ntransportation options available in boston include roxbury crossing station, located 0.7 miles from 1 cedar sq. 1 cedar sq is near general edward lawrence logan international, located 6.3 miles or 13 minutes away.\ntransit / subway distance\nroxbury crossing station\nwalk: 13 min 0.7 mi\njackson square station\nwalk: 14 min 0.8 mi\nstony brook station\ndrive: 3 min 1.4 mi\nmuseum of fine arts station\ndrive: 3 min 1.5 mi\nlongwood medical area station\ndrive: 3 min 1.5 mi\ncommuter rail distance\nnewmarket\ndrive: 4 min 1.7 mi\nuphams corner\ndrive: 3 min 1.7 mi\nruggles station\ndrive: 4 min 1.8 mi\nfour corners/geneva\ndrive: 5 min 2.2 mi\nyawkey\ndrive: 11 min 5.5 mi\nairports distance\ngeneral edward lawrence logan international\ndrive: 13 min 6.3 mi\n\nvery walkable\n79\nwalk score®\nout of 100\nif you enjoy walking, you’ll enjoy renting in this area! it’s a very walkable neighborhood.\nexcellent transit\n81\ntransit score®\nout of 100\nyou’ll have excellent transit living in this area, with several nearby transit stops.\nbikeable\n53\nbike score®\nout of 100\nwhile there’s some bike infrastructure in this area, you’ll still need a car for many  ...
# {'PROPERTY_ID': 'property_234', 'PROPERTY_TITLE': '4 cedar st', 'PROPERTY_ADDRESS': '4 cedar st, boston, ma 02119', 'MONTHLY_RENT': 'rent: $9,500', 'BEDROOMS': '6 bedrooms', 'BATHROOMS': '4.5 bathrooms', 'SQUARE_FEET': '3,000 square feet', 'AVAILABILITY': 'available sep 1, 2025', 'DEPOSIT': '$9,500 deposit', 'LEASE_DURATION': '12 month lease', 'HOUSE_FEATURES': 'amenities: wi-fi, washer/dryer, tub/shower, dishwasher, kitchen', 'UTILITIES_INCLUDED': None, 'ABOUT_PROPERTY_DETAILS': 'spacious 7-bedroom, 4.5-bathroom home for rent in mission hill\n\nlocated in the bustling mission hill area, this expansive 7-bedroom, 4.5-bathroom residence is perfect for larger groups or student housing. offering a blend of space and convenience, this home provides comfortable living near boston’s top universities, medical centers, and public transit options.\n\nkey features:\nopen living and dining areas:\ngenerous shared spaces, ideal for gatherings, studying, and relaxing.\nupdated kitchen:\nequipped with modern appliances, including a refrigerator, stove, and dishwasher.\nample counter space and cabinetry designed to accommodate larger households.\nseven spacious bedrooms:\neach bedroom provides room for a bed, desk, and personal storage, perfect for individual or shared use.\nfour and a half bathrooms:\nwell-placed bathrooms across floors for convenience, with full baths and a half bath.\nhardwood and tile flooring:\neasy-to-clean surfaces throughout, adding warmth and durability to the home.\nin-unit laundry:\nincludes washer and dryer, making laundry convenient for everyone.\noutdoor area:\naccess to a private backyard area, great for fresh air, studying, or socializing outdoors.\nparking:\nlimited off-street parking is available.\nprime location highlights:\nmission hill neighborhood:\nnear coffee shops, grocery stores, and dining, plus quick access to public transit options connecting to downtown boston and surrounding areas.\nnearby schools:\nnortheastern university (1 mile) – a brief commute by green line.\nmassachusetts college of pharmacy and health sciences (mcphs) (0.7 miles).\nwentworth institute of technology (0.8 miles).\nharvard medical school and other longwood medical area institutions (1.2 miles).\nnearby hospitals:\nbrigham and women’s hospital (1 mile) and beth israel deaconess medical center (1.1 miles) – key longwood medical area institutions.\nboston children’s hospital (1.2 miles).\nnearby parks:\nclose to mclaughlin playground and mission hill playground.\ndining & essentials:\ngroceries: near stop & shop and whole foods.\ndining: local favorites like milkweed, penguin pizza, and laughing monk café.\npublic transit access:\nproximity to green line (e) and orange line stations, as well as multiple bus routes for convenient travel.\n\nthis 7-bedroom, 4.5-bath home at 1 cedar st. is ready to provide the space and amenities for comfortable group living in mission hill. contact us to set up a tour! 4 cedar st is a house located in suffolk county and the 02119 zip code. this area is served by the boston public schools attendance zone.', 'NEIGHBORHOOD_DETAILS': 'twenty minutes southwest of downtown boston sits highland park, a primarily- residential neighborhood full of beautiful historic homes and apartments along tree-lined streets. the community features over a dozen parks and public green spaces, giving all residents easy access to trails, playgrounds, and historic sites wherever they may live. the local dining scene is quite unique, with several african and middle eastern restaurants and cafes around the neighborhood. mbta rail service on the west side of the neighborhood makes it easy for folks to get around the city for or leisure.', 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\nwentworth inst. of technology\ndrive: 3 min 1.3 mi\nmassart\ndrive: 3 min 1.7 mi\nmcphs university, boston\ndrive: 3 min 1.8 mi\nnortheastern university\ndrive: 5 min 2.0 mi\n4 cedar st is within 3 minutes or 1.3  ...
# {'PROPERTY_ID': 'property_217', 'PROPERTY_TITLE': '1 cedar sq', 'PROPERTY_ADDRESS': '1 cedar sq, boston, ma 02119', 'MONTHLY_RENT': 'rent: $8,750', 'BEDROOMS': '6 bedrooms', 'BATHROOMS': '4.5 bathrooms', 'SQUARE_FEET': '9,999 square feet', 'AVAILABILITY': 'available sep 1, 2025', 'DEPOSIT': '$8,750 deposit', 'LEASE_DURATION': '12 month lease', 'HOUSE_FEATURES': 'amenities: washer/dryer, air conditioning, heating, cable ready, tub/shower', 'UTILITIES_INCLUDED': None, 'ABOUT_PROPERTY_DETAILS': 'entire 7 bedroom 4.5 bathroom house !\n—————\ncentral air \nlaundry in unit\ndishwasher \n—————\n7 bedrooms ****(not 6)\n4.5 bathrooms \n3 floors\nupdated kitchen\nupdated bathrooms\nhardwood floors \n—————-\n9/1/25\n—————\nmike swann\nmichael swann real estate 1 cedar sq is a house located in suffolk county and the 02119 zip code. this area is served by the boston public schools attendance zone.', 'NEIGHBORHOOD_DETAILS': 'twenty minutes southwest of downtown boston sits highland park, a primarily- residential neighborhood full of beautiful historic homes and apartments along tree-lined streets. the community features over a dozen parks and public green spaces, giving all residents easy access to trails, playgrounds, and historic sites wherever they may live. the local dining scene is quite unique, with several african and middle eastern restaurants and cafes around the neighborhood. mbta rail service on the west side of the neighborhood makes it easy for folks to get around the city for or leisure.', 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\nwentworth inst. of technology\ndrive: 3 min 1.3 mi\nmassart\ndrive: 3 min 1.7 mi\nmcphs university, boston\ndrive: 3 min 1.8 mi\nnortheastern university\ndrive: 5 min 2.1 mi\n1 cedar sq is within 3 minutes or 1.3 miles from wentworth inst. of technology. it is also near mcphs university, boston and massart.\nschools\npublic schools private schools\nhigginson/lewis k-8\npublic elementary & middle school\ngrades 3-8\n177 students\nattendance zone\n2\nout of 10\nhale elementary school\npublic elementary school\ngrades pk-6\n169 students\nattendance zone\n6\nout of 10\no'bryant school math/science\npublic middle & high school\ngrades 7-12\n1,567 students\nattendance zone\n8\nout of 10\njames p timilty middle\npublic middle school\ngrades 6-8\n205 students\nattendance zone\nmadison park high\npublic high school\ngrades 9-12\n1,087 students\nattendance zone\n1\nout of 10\nboston day and evening academy charter school\ncharter high school\ngrades 9-10 & 12\n321 students\nattendance zone\n1\nout of 10\nschool data provided by greatschools\n\ntransportation\ntransportation options available in boston include roxbury crossing station, located 0.7 miles from 1 cedar sq. 1 cedar sq is near general edward lawrence logan international, located 6.3 miles or 13 minutes away.\ntransit / subway distance\nroxbury crossing station\nwalk: 13 min 0.7 mi\njackson square station\nwalk: 14 min 0.8 mi\nstony brook station\ndrive: 3 min 1.4 mi\nmuseum of fine arts station\ndrive: 3 min 1.5 mi\nlongwood medical area station\ndrive: 3 min 1.5 mi\ncommuter rail distance\nnewmarket\ndrive: 4 min 1.7 mi\nuphams corner\ndrive: 3 min 1.7 mi\nruggles station\ndrive: 4 min 1.8 mi\nfour corners/geneva\ndrive: 5 min 2.2 mi\nyawkey\ndrive: 11 min 5.5 mi\nairports distance\ngeneral edward lawrence logan international\ndrive: 13 min 6.3 mi\n\nvery walkable\n79\nwalk score®\nout of 100\nif you enjoy walking, you’ll enjoy renting in this area! it’s a very walkable neighborhood.\nexcellent transit\n81\ntransit score®\nout of 100\nyou’ll have excellent transit living in this area, with several nearby transit stops.\nbikeable\n53\nbike score®\nout of 100\nwhile there’s some bike infrastructure in this area, you’ll still need a car for many errands.\n-\n-\nsoundscore™\nout of 100\ntraffic:\n-\nairport:\n-\nbusinesses:\n-\nscore provided by walk score\n\npoints of interest\ntime and distance from 1 cedar sq.\nsho ...
# {'PROPERTY_ID': 'property_33', 'PROPERTY_TITLE': '1 cedar sq', 'PROPERTY_ADDRESS': '1 cedar sq, boston, ma 02119', 'MONTHLY_RENT': 'rent: $9,500', 'BEDROOMS': '6 bedrooms', 'BATHROOMS': '4.5 bathrooms', 'SQUARE_FEET': '2,000 square feet', 'AVAILABILITY': 'available sep 1, 2025', 'DEPOSIT': None, 'LEASE_DURATION': '12 month lease', 'HOUSE_FEATURES': 'amenities: washer/dryer, storage space', 'UTILITIES_INCLUDED': 'water, trash removal, sewer', 'ABOUT_PROPERTY_DETAILS': 'this spacious 7-bedroom, 4.5-bathroom home at 1 cedar sq offers 3,000 square feet of living space. the living room provides ample room for relaxation and entertainment, while the bedrooms are designed for comfort and privacy. the bathrooms include a combination of tub and shower options, catering to various preferences. additional amenities feature convenient storage space and an in-unit washer and dryer for laundry needs. the exterior of the property includes a manageable yard, suitable for outdoor activities. this rental is available at a competitive price, making it an attractive option for larger groups. close proximity to local amenities enhances the overall convenience of this location. interested renters are encouraged to schedule a viewing to appreciate the space fully. commute to north eastern university is 20 min or less. 1 cedar sq is a house located in suffolk county and the 02119 zip code. this area is served by the boston public schools attendance zone.', 'NEIGHBORHOOD_DETAILS': 'twenty minutes southwest of downtown boston sits highland park, a primarily- residential neighborhood full of beautiful historic homes and apartments along tree-lined streets. the community features over a dozen parks and public green spaces, giving all residents easy access to trails, playgrounds, and historic sites wherever they may live. the local dining scene is quite unique, with several african and middle eastern restaurants and cafes around the neighborhood. mbta rail service on the west side of the neighborhood makes it easy for folks to get around the city for or leisure.', 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\nwentworth inst. of technology\ndrive: 3 min 1.3 mi\nmassart\ndrive: 3 min 1.7 mi\nmcphs university, boston\ndrive: 3 min 1.8 mi\nnortheastern university\ndrive: 5 min 2.1 mi\n1 cedar sq is within 3 minutes or 1.3 miles from wentworth inst. of technology. it is also near mcphs university, boston and massart.\nschools\npublic schools private schools\nhigginson/lewis k-8\npublic elementary & middle school\ngrades 3-8\n177 students\nattendance zone\n2\nout of 10\nhale elementary school\npublic elementary school\ngrades pk-6\n169 students\nattendance zone\n6\nout of 10\no'bryant school math/science\npublic middle & high school\ngrades 7-12\n1,567 students\nattendance zone\n8\nout of 10\njames p timilty middle\npublic middle school\ngrades 6-8\n205 students\nattendance zone\nmadison park high\npublic high school\ngrades 9-12\n1,087 students\nattendance zone\n1\nout of 10\nboston day and evening academy charter school\ncharter high school\ngrades 9-10 & 12\n321 students\nattendance zone\n1\nout of 10\nschool data provided by greatschools\n\ntransportation\ntransportation options available in boston include roxbury crossing station, located 0.7 miles from 1 cedar sq. 1 cedar sq is near general edward lawrence logan international, located 6.3 miles or 13 minutes away.\ntransit / subway distance\nroxbury crossing station\nwalk: 13 min 0.7 mi\njackson square station\nwalk: 14 min 0.8 mi\nstony brook station\ndrive: 3 min 1.4 mi\nmuseum of fine arts station\ndrive: 3 min 1.5 mi\nlongwood medical area station\ndrive: 3 min 1.5 mi\ncommuter rail distance\nnewmarket\ndrive: 4 min 1.7 mi\nuphams corner\ndrive: 3 min 1.7 mi\nruggles station\ndrive: 4 min 1.8 mi\nfour corners/geneva\ndrive: 5 min 2.2 mi\nyawkey\ndrive: 11 min 5.5 mi\nairports distance\ngeneral edward lawrence logan international\ndrive: 13 min 6.3 mi\n\nvery walkable\n79 ...
# {'PROPERTY_ID': 'property_223', 'PROPERTY_TITLE': '3 cedar st', 'PROPERTY_ADDRESS': '3 cedar st, boston, ma 02119', 'MONTHLY_RENT': 'rent: $8,750', 'BEDROOMS': '6 bedrooms', 'BATHROOMS': '4.5 bathrooms', 'SQUARE_FEET': '3,000 square feet', 'AVAILABILITY': 'available sep 1, 2025', 'DEPOSIT': '$8,750 deposit', 'LEASE_DURATION': '12 month lease', 'HOUSE_FEATURES': 'amenities: washer/dryer, dishwasher, island kitchen, eat-in kitchen, kitchen', 'UTILITIES_INCLUDED': 'built in 2020', 'ABOUT_PROPERTY_DETAILS': "huge single family house in fort hill - new construction in 2020 - featuring:\n- hardwood flooring throughout!\n- high end, fully equipped eat in kitchen!\n- stainless appliances - dishwasher!\n- granite kitchen island w/ breakfast bar!\n- spacious & sunny living room!\n- 7 generously sized bedrooms!\n- 4 full & 1 half updated bathrooms!\n- convenient in unit washer & dryer!\n\ngreat location in roxbury's fort hill, a nice alternative to mission hill but just as conveniently located! easy access to orange line at jackson station & roxbury crossing as well as multiple major mbta bus routes! convenient to many local schools and universities including northeastern, simmons, berklee, emmanuel, wheelock, mass college of pharmacy, ne conservatory, school of the museum of fine arts, mass college of art, wentworth, roxbury community college, boston architectural college, boston latin high school, harvard medical school, and more! nearby longwood medical area's many hospitals such as brigham & women's, beth israel, children's hospital. close to egleston square, jackson square, roxbury crossing, jamaica plain, franklin park & the zoo, and lively nubian square! located close to shopping, dining, bars, parks, nightlife, and all the excitement of boston! 3 cedar st is a house located in suffolk county and the 02119 zip code. this area is served by the boston public schools attendance zone.", 'NEIGHBORHOOD_DETAILS': 'twenty minutes southwest of downtown boston sits highland park, a primarily- residential neighborhood full of beautiful historic homes and apartments along tree-lined streets. the community features over a dozen parks and public green spaces, giving all residents easy access to trails, playgrounds, and historic sites wherever they may live. the local dining scene is quite unique, with several african and middle eastern restaurants and cafes around the neighborhood. mbta rail service on the west side of the neighborhood makes it easy for folks to get around the city for or leisure.', 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\nwentworth inst. of technology\ndrive: 3 min 1.3 mi\nmassart\ndrive: 3 min 1.8 mi\nmcphs university, boston\ndrive: 4 min 1.9 mi\nnortheastern university\ndrive: 5 min 2.0 mi\n3 cedar st is within 3 minutes or 1.3 miles from wentworth inst. of technology. it is also near northeastern university and mcphs university, boston.\nschools\npublic schools private schools\nhigginson/lewis k-8\npublic elementary & middle school\ngrades 3-8\n177 students\nattendance zone\n2\nout of 10\nhale elementary school\npublic elementary school\ngrades pk-6\n169 students\nattendance zone\n6\nout of 10\no'bryant school math/science\npublic middle & high school\ngrades 7-12\n1,567 students\nattendance zone\n8\nout of 10\njames p timilty middle\npublic middle school\ngrades 6-8\n205 students\nattendance zone\nmadison park high\npublic high school\ngrades 9-12\n1,087 students\nattendance zone\n1\nout of 10\nboston day and evening academy charter school\ncharter high school\ngrades 9-10 & 12\n321 students\nattendance zone\n1\nout of 10\nschool data provided by greatschools\n\ntransportation\ntransportation options available in boston include roxbury crossing station, located 0.7 miles from 3 cedar st. 3 cedar st is near general edward lawrence logan international, located 6.2 miles or 12 minutes away.\ntransit / subway distance\nroxbury crossing station\nwalk: 14 min 0.7 mi\njackson square station\nw ...
# {'PROPERTY_ID': 'property_3', 'PROPERTY_TITLE': '12 dalrymple st', 'PROPERTY_ADDRESS': '12 dalrymple st, boston, ma 02130', 'MONTHLY_RENT': 'rent: $4,450', 'BEDROOMS': '5 bedrooms', 'BATHROOMS': '2 bathrooms', 'SQUARE_FEET': '1,900 square feet', 'AVAILABILITY': 'available now', 'DEPOSIT': None, 'LEASE_DURATION': None, 'HOUSE_FEATURES': 'amenities: kitchen, refrigerator', 'UTILITIES_INCLUDED': None, 'ABOUT_PROPERTY_DETAILS': '3rd floor 4 bedroom 2 bath with renovated kitchen and bath a block to stony brook orange line. consisting of the 3rd floor and renovated attic space, this unit offers amazing space across 8 rooms. the main floor includes the 4 bedrooms, office, bathroom and eat-in kitchen includes stainless steel appliances - gas range, refrigerator, dishwasher, and granite countertops and a large pantry. the renovated attic offers 3 rooms for storage or office space and the 2nd bathroom. refinished hardwood floors throughout and tile in the bathroom and kitchen.gas heat. laundry on site. dedicated use of first-floor back deck. located on a quiet one way side street. 12 dalrymple st is a house located in suffolk county and the 02130 zip code. this area is served by the boston public schools attendance zone.', 'NEIGHBORHOOD_DETAILS': 'the tree-lined streets of egleston square are full of big, beautiful victorian-style homes and vintage red brick buildings, an architectural feast for the eyes. the diverse population brings an eclectic mix of artistic, cultural, and culinary influences to the community, resulting in one of the more unique neighborhood personalities in boston. residents enjoy enviable access to franklin park, which borders the neighborhood to the southeast; white stadium, franklin park playstead, and the trail network are just a short walk from anywhere in egleston square. one of the most popular attractions is the samuel adams brewery on the west side of the neighborhood, which is as popular with locals as it is with visitors. be sure to stop by the saturday farmers’ market throughout the summer… it’s the best place to find fresh groceries, food trucks, local art, and live music all in one place.', 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\nwentworth inst. of technology\ndrive: 5 min 2.0 mi\nmassart\ndrive: 5 min 2.5 mi\nmcphs university, boston\ndrive: 5 min 2.6 mi\nsimmons college\ndrive: 8 min 3.1 mi\n12 dalrymple st is within 5 minutes or 2.0 miles from wentworth inst. of technology. it is also near mcphs university, boston and massart.\nschools\npublic schools private schools\nhernandez k-8 school\npublic elementary & middle school\ngrades pk-8\n425 students\nattendance zone\n4\nout of 10\nmendell elementary school\npublic elementary school\ngrades pk-6\n312 students\nattendance zone\n6\nout of 10\ndearborn middle school\npublic middle & high school\ngrades 6-12\n541 students\nattendance zone\n3\nout of 10\nboston latin academy\npublic middle & high school\ngrades 7-12\n1,723 students\nattendance zone\n7\nout of 10\negleston community high school\npublic high school\ngrades 9-12\n90 students\nattendance zone\n1\nout of 10\nschool data provided by greatschools\n\ntransportation\ntransportation options available in boston include stony brook station, located 0.3 miles from 12 dalrymple st. 12 dalrymple st is near general edward lawrence logan international, located 7.9 miles or 16 minutes away.\ntransit / subway distance\nstony brook station\nwalk: 5 min 0.3 mi\ngreen street station\nwalk: 10 min 0.5 mi\njackson square station\nwalk: 13 min 0.7 mi\nheath street station\ndrive: 4 min 1.4 mi\nroxbury crossing station\ndrive: 4 min 1.6 mi\ncommuter rail distance\nforest hills\ndrive: 4 min 1.8 mi\nfour corners/geneva\ndrive: 7 min 2.5 mi\nruggles station\ndrive: 6 min 2.6 mi\ntalbot avenue\ndrive: 7 min 3.0 mi\nuphams corner\ndrive: 7 min 3.2 mi\nairports distance\ngeneral edward lawrence logan international\ndrive: 16 min 7.9 mi\n\nwalker's paradise\n90\nwalk score®\nout of  ...
# {'PROPERTY_ID': 'property_252', 'PROPERTY_TITLE': '897 canterbury st', 'PROPERTY_ADDRESS': '897 canterbury st, boston, ma 02131', 'MONTHLY_RENT': 'rent: $2,495', 'BEDROOMS': '2 bedrooms', 'BATHROOMS': '1 bathrooms', 'SQUARE_FEET': '950 square feet', 'AVAILABILITY': 'available now', 'DEPOSIT': '$2,495 deposit', 'LEASE_DURATION': '12 month lease', 'HOUSE_FEATURES': 'amenities: washer/dryer hookup, kitchen', 'UTILITIES_INCLUDED': None, 'ABOUT_PROPERTY_DETAILS': 'located at 897 canterbury st in roslindale, this charming 2-bedroom, 1-bath apartment offers comfortable living in a quiet, residential neighborhood. the unit features two spacious bedrooms, a full bath, and a bright, open living area perfect for relaxing or entertaining. the kitchen is fully equipped with modern appliances, and water is included in the rent. off-street parking is provided for added convenience. with easy access to public transportation, local shops, restaurants, and parks, this apartment is ideal for anyone looking for a well-maintained, affordable home in a great location. 897 canterbury st is a house located in suffolk county and the 02131 zip code. this area is served by the boston public schools attendance zone.', 'NEIGHBORHOOD_DETAILS': 'lower washington-mount hope is a walkable neighborhood about eight miles south of boston via interstate 93 or public transit. despite this area’s dense population, lower washington-mount hope has many wooded areas, and large parks like bussey brook meadow and franklin park surround the neighborhood. along with residential neighborhoods, a few shops and eateries can be found in town along american legion highway. many residents travel to the western corner of town to get to the shopping plaza off corinth street for all the necessities. the western part of the neighborhood is also where most of the rentals in this area are located. apartments, condos, and townhomes ranging from moderately priced to luxury can be found here.', 'ADDITIONAL_PROPERTY_DETAILS': "education\ncolleges & universities distance\ncurry college\ndrive: 9 min 3.5 mi\nwentworth inst. of technology\ndrive: 9 min 4.6 mi\nmassart\ndrive: 9 min 5.1 mi\nmcphs university, boston\ndrive: 9 min 5.2 mi\n897 canterbury st is within 9 minutes or 3.5 miles from curry college. it is also near wentworth inst. of technology and mcphs university, boston.\nschools\npublic schools private schools\nphilbrick elementary school\npublic elementary school\ngrades pk-6\n114 students\nattendance zone\nhaley pilot school\npublic elementary & middle school\ngrades pk-8\n371 students\nattendance zone\n4\nout of 10\nwashington irving middle\npublic middle school\ngrades 6-8\n133 students\nattendance zone\ntechboston academy\npublic middle & high school\ngrades 6-12\n871 students\nattendance zone\n2\nout of 10\nboston community leadership academy\npublic middle & high school\ngrades 7-12\n598 students\nattendance zone\n2\nout of 10\nschool data provided by greatschools\n\ntransportation\ntransportation options available in boston include forest hills station, located 1.7 miles from 897 canterbury st. 897 canterbury st is near general edward lawrence logan international, located 9.9 miles or 19 minutes away.\ntransit / subway distance\nforest hills station\ndrive: 3 min 1.7 mi\nmattapan station\ndrive: 4 min 1.8 mi\ncapen street station\ndrive: 5 min 2.4 mi\nvalley road station\ndrive: 5 min 2.5 mi\ngreen street station\ndrive: 5 min 2.6 mi\ncommuter rail distance\nroslindale village\ndrive: 4 min 1.3 mi\nblue hill avenue\ndrive: 3 min 1.4 mi\nforest hills\ndrive: 3 min 1.7 mi\nbellevue\ndrive: 6 min 2.0 mi\nmorton street\ndrive: 5 min 2.4 mi\nairports distance\ngeneral edward lawrence logan international\ndrive: 19 min 9.9 mi\n\nvery walkable\n73\nwalk score®\nout of 100\nif you enjoy walking, you’ll enjoy renting in this area! it’s a very walkable neighborhood.\ngood transit\n55\ntransit score®\nout of 100\nthe area around this property has good transit with many nearby transpo ...

# %%
import snowflake.connector
import json

# Load latest metadata entry from local JSON
with open("query_metadata_log.json", "r") as f:
    data = json.load(f)

latest = data[-1]
user_query = latest["user_query"]
metadata_filters = latest["metadata_extracted"]

# Sanitize user query for embedding call inside SQL
user_query_safe = user_query.replace("'", "''")

# Connect to Snowflake
conn = snowflake.connector.connect(
    account="SFEDU02-PDB57018",
    user="BADGER",
    password="",
    role="TRAINING_ROLE",
    warehouse="LISTINGS_WH",
    database="LISTINGS",
    schema="PUBLIC"
)
cur = conn.cursor()

# Build metadata filter WHERE clause
filter_clauses = []
for key, value in metadata_filters.items():
    if value:
        if isinstance(value, (int, float)):
            filter_clauses.append(f"{key} = {value}")
        elif isinstance(value, str) and value.strip().startswith("<"):
            num = value.strip("<$ ")
            filter_clauses.append(f"TRY_TO_NUMBER(REGEXP_REPLACE({key}, '[^0-9.]', '')) < {num}")
        elif isinstance(value, str) and value.strip().startswith(">"):
            num = value.strip(">$ ")
            filter_clauses.append(f"TRY_TO_NUMBER(REGEXP_REPLACE({key}, '[^0-9.]', '')) > {num}")
        elif isinstance(value, bool):
            filter_clauses.append(f"{key} = {str(value).upper()}")
        else:
            filter_clauses.append(f"{key} ILIKE '%{value}%'")

where_clause = " AND ".join(filter_clauses)
if where_clause:
    where_clause = f"WHERE {where_clause}"

# SQL with metadata filters + semantic embedding
sql_with_filters = f"""
SELECT *,
  VECTOR_COSINE_SIMILARITY(
    PROPERTIES_EMBEDDING,
    SNOWFLAKE.CORTEX.EMBED_TEXT_1024('snowflake-arctic-embed-l-v2.0', '{user_query_safe}')
  ) AS similarity
FROM PROPERTIES_WITH_EMBEDDINGS
{where_clause}
ORDER BY similarity DESC
LIMIT 10;
"""

print("Executing hybrid query with filters\n")
print(sql_with_filters)

cur.execute(sql_with_filters)
results = cur.fetchall()

# Fallback if no results with metadata filters
if not results:
    print("\nNo results found with metadata filters. Trying semantic-only fallback\n")

    sql_no_filters = f"""
    SELECT *,
      VECTOR_COSINE_SIMILARITY(
        PROPERTIES_EMBEDDING,
        SNOWFLAKE.CORTEX.EMBED_TEXT_1024('snowflake-arctic-embed-l-v2.0', '{user_query_safe}')
      ) AS similarity
    FROM PROPERTIES_WITH_EMBEDDINGS
    ORDER BY similarity DESC
    LIMIT 10;
    """

    print("🔁 Fallback Query:\n", sql_no_filters)
    cur.execute(sql_no_filters)
    results = cur.fetchall()

# Get columns after execution
columns = [col[0] for col in cur.description]

# Only show selected fields
selected_fields = [
    "PROPERTY_ID",
    "PROPERTY_TITLE",
    "PROPERTY_ADDRESS",
    "MONTHLY_RENT",
    "BEDROOMS",
    "BATHROOMS",
    "SQUARE_FEET",
    "AVAILABILITY",
    "DEPOSIT",
    "LEASE_DURATION",
    "HOUSE_FEATURES",
    "UTILITIES_INCLUDED",
    "similarity"
]

# Display
if not results:
    print("\nNo matching properties found even after fallback.\n")
else:
    print("\nTop matching properties:\n")
    for row in results:
        record = dict(zip(columns, row))
        output = {key: record.get(key) for key in selected_fields}
        print(json.dumps(output, indent=2))

cur.close()
conn.close()
# Out:
# Executing hybrid query with filters
#
#
# SELECT *,
#   VECTOR_COSINE_SIMILARITY(
#     PROPERTIES_EMBEDDING,
#     SNOWFLAKE.CORTEX.EMBED_TEXT_1024('snowflake-arctic-embed-l-v2.0', 'Give me properties with 5 bedrooms and rent can be 5200  and is closest to Wentworth Institute of Technology based on drive distance in miles')
#   ) AS similarity
# FROM PROPERTIES_WITH_EMBEDDINGS
# WHERE BEDROOMS ILIKE '%5 BEDROOMS%' AND MONTHLY_RENT ILIKE '%Rent: $5,200%' AND PROPERTY_ADDRESS ILIKE '%Wentworth Institute of Technology%'
# ORDER BY similarity DESC
# LIMIT 10;
#
#
# No results found with metadata filters. Trying semantic-only fallback
#
# 🔁 Fallback Query:
#
#     SELECT *,
#       VECTOR_COSINE_SIMILARITY(
#         PROPERTIES_EMBEDDING,
#         SNOWFLAKE.CORTEX.EMBED_TEXT_1024('snowflake-arctic-embed-l-v2.0', 'Give me properties with 5 bedrooms and rent can be 5200  and is closest to Wentworth Institute of Technology based on drive distance in miles')
#       ) AS similarity
#     FROM PROPERTIES_WITH_EMBEDDINGS
#     ORDER BY similarity DESC
#     LIMIT 10;
#
#
# Top matching properties:
#
# {
#   "PROPERTY_ID": "property_181",
#   "PROPERTY_TITLE": "13 gordon st",
#   "PROPERTY_ADDRESS": "13 gordon st, boston, ma 02130",
#   "MONTHLY_RENT": "rent: $5,200",
#   "BEDROOMS": "5 bedrooms",
#   "BATHROOMS": "2.5 bathrooms",
#   "SQUARE_FEET": "9,999 square feet",
#   "AVAILABILITY": "available sep 1, 2025",
#   "DEPOSIT": "$5,200 deposit",
#   "LEASE_DURATION": "12 month lease",
#   "HOUSE_FEATURES": "amenities: washer/dryer",
#   "UTILITIES_INCLUDED": null,
#   "similarity": null
# }
# {
#   "PROPERTY_ID": "property_208",
#   "PROPERTY_TITLE": "1 cedar st",
#   "PROPERTY_ADDRESS": "1 cedar st, boston, ma 02119",
#   "MONTHLY_RENT": "rent: $8,750",
#   "BEDROOMS": "7 bedrooms",
#   "BATHROOMS": "4.5 bathrooms",
#   "SQUARE_FEET": "3,000 square feet",
#   "AVAILABILITY": "available now",
#   "DEPOSIT": "$9,150 deposit",
#   "LEASE_DURATION": null,
#   "HOUSE_FEATURES": null,
#   "UTILITIES_INCLUDED": null,
#   "similarity": null
# }
# {
#   "PROPERTY_ID": "property_169",
#   "PROPERTY_TITLE": "1110 washington st",
#   "PROPERTY_ADDRESS": "1110 washington st, boston, ma 02124",
#   "MONTHLY_RENT": "rent: $3,600",
#   "BEDROOMS": "2 bedrooms",
#   "BATHROOMS": "1.5 bathrooms",
#   "SQUARE_FEET": "1,932 square feet",
#   "AVAILABILITY": "available now",
#   "DEPOSIT": "$4,400 deposit",
#   "LEASE_DURATION": null,
#   "HOUSE_FEATURES": null,
#   "UTILITIES_INCLUDED": null,
#   "similarity": null
# }
# {
#   "PROPERTY_ID": "property_168",
#   "PROPERTY_TITLE": "1 cedar sq",
#   "PROPERTY_ADDRESS": "1 cedar sq, boston, ma 02119",
#   "MONTHLY_RENT": "rent: $9,500",
#   "BEDROOMS": "6 bedrooms",
#   "BATHROOMS": "4.5 bathrooms",
#   "SQUARE_FEET": "3,000 square feet",
#   "AVAILABILITY": "available sep 1, 2025",
#   "DEPOSIT": null,
#   "LEASE_DURATION": "12 month lease",
#   "HOUSE_FEATURES": "amenities: washer/dryer, air conditioning, heating, cable ready, storage space",
#   "UTILITIES_INCLUDED": "water, trash removal, sewer",
#   "similarity": null
# }
# {
#   "PROPERTY_ID": "property_234",
#   "PROPERTY_TITLE": "4 cedar st",
#   "PROPERTY_ADDRESS": "4 cedar st, boston, ma 02119",
#   "MONTHLY_RENT": "rent: $9,500",
#   "BEDROOMS": "6 bedrooms",
#   "BATHROOMS": "4.5 bathrooms",
#   "SQUARE_FEET": "3,000 square feet",
#   "AVAILABILITY": "available sep 1, 2025",
#   "DEPOSIT": "$9,500 deposit",
#   "LEASE_DURATION": "12 month lease",
#   "HOUSE_FEATURES": "amenities: wi-fi, washer/dryer, tub/shower, dishwasher, kitchen",
#   "UTILITIES_INCLUDED": null,
#   "similarity": null
# }
# {
#   "PROPERTY_ID": "property_217",
#   "PROPERTY_TITLE": "1 cedar sq",
#   "PROPERTY_ADDRESS": "1 cedar sq, boston, ma 02119",
#   "MONTHLY_RENT": "rent: $8,750",
#   "BEDROOMS": "6 bedrooms",
#   "BATHROOMS": "4.5 bathrooms",
#   "SQUARE_FEET": "9,999 square feet",
#   "AVAILABILITY": "available sep 1, 2025",
#   "DEPOSIT": "$8,750 deposit",
#   "LEASE_DURATION": "12 month lease",
#   "HOUSE_FEATURES": "amenities: washer/dryer, air conditioning, heating, cable ready, tub/shower",
#   "UTILITIES_INCLUDED": null,
#   "similarity": null
# }
# {
#   "PROPERTY_ID": "property_33",
#   "PROPERTY_TITLE": "1 cedar sq",
#   "PROPERTY_ADDRESS": "1 cedar sq, boston, ma 02119",
#   "MONTHLY_RENT": "rent: $9,500",
#   "BEDROOMS": "6 bedrooms",
#   "BATHROOMS": "4.5 bathrooms",
#   "SQUARE_FEET": "2,000 square feet",
#   "AVAILABILITY": "available sep 1, 2025",
#   "DEPOSIT": null,
#   "LEASE_DURATION": "12 month lease",
#   "HOUSE_FEATURES": "amenities: washer/dryer, storage space",
#   "UTILITIES_INCLUDED": "water, trash removal, sewer",
#   "similarity": null
# }
# {
#   "PROPERTY_ID": "property_223",
#   "PROPERTY_TITLE": "3 cedar st",
#   "PROPERTY_ADDRESS": "3 cedar st, boston, ma 02119",
#   "MONTHLY_RENT": "rent: $8,750",
#   "BEDROOMS": "6 bedrooms",
#   "BATHROOMS": "4.5 bathrooms",
#   "SQUARE_FEET": "3,000 square feet",
#   "AVAILABILITY": "available sep 1, 2025",
#   "DEPOSIT": "$8,750 deposit",
#   "LEASE_DURATION": "12 month lease",
#   "HOUSE_FEATURES": "amenities: washer/dryer, dishwasher, island kitchen, eat-in kitchen, kitchen",
#   "UTILITIES_INCLUDED": "built in 2020",
#   "similarity": null
# }
# {
#   "PROPERTY_ID": "property_3",
#   "PROPERTY_TITLE": "12 dalrymple st",
#   "PROPERTY_ADDRESS": "12 dalrymple st, boston, ma 02130",
#   "MONTHLY_RENT": "rent: $4,450",
#   "BEDROOMS": "5 bedrooms",
#   "BATHROOMS": "2 bathrooms",
#   "SQUARE_FEET": "1,900 square feet",
#   "AVAILABILITY": "available now",
#   "DEPOSIT": null,
#   "LEASE_DURATION": null,
#   "HOUSE_FEATURES": "amenities: kitchen, refrigerator",
#   "UTILITIES_INCLUDED": null,
#   "similarity": null
# }
# {
#   "PROPERTY_ID": "property_252",
#   "PROPERTY_TITLE": "897 canterbury st",
#   "PROPERTY_ADDRESS": "897 canterbury st, boston, ma 02131",
#   "MONTHLY_RENT": "rent: $2,495",
#   "BEDROOMS": "2 bedrooms",
#   "BATHROOMS": "1 bathrooms",
#   "SQUARE_FEET": "950 square feet",
#   "AVAILABILITY": "available now",
#   "DEPOSIT": "$2,495 deposit",
#   "LEASE_DURATION": "12 month lease",
#   "HOUSE_FEATURES": "amenities: washer/dryer hookup, kitchen",
#   "UTILITIES_INCLUDED": null,
#   "similarity": null
# }
